# %% [markdown]
# # Problem Statement

# %% [markdown]
# # Load the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Laod the Datset

# %%
house=pd.read_csv("C:/Users/Laptop House/Data Science Intern/Intern Projects/House_Price_Prediction/Dataset/kc_house_data.csv")

# %% [markdown]
# # Top 5 Records

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# # Last 5 Rescords

# %%
house.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %% [markdown]
# **Remove the unecessary and quasi constant columns**

# %% [markdown]
# # Quasi-Constant Columns
# **Those columns whose value can't the whole data**

# %%
house.drop(columns=['id','waterfront','view','yr_renovated','zipcode'],inplace=True)

# %%
house.sample(30)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 8598   20140611T000000   290000.0         3       1.75         1520     15090
# 14759  20141024T000000   239000.0         3       1.50         1330      6540
# 18857  20141119T000000   520000.0         5       1.75         2040      5280
# 12112  20140604T000000   371000.0         3       1.50         1420      4500
# 18220  20150318T000000   305000.0         3       2.25         1370      6600
# 17831  20140612T000000   600000.0         3       2.25         1480      5400
# 20262  20150501T000000   550000.0         4       2.50         3220      9328
# 2177   20150316T000000  1085000.0         3       2.50         3630     11019
# 13618  20141224T000000   310000.0         2       1.00         1400      4500
# 1701   20140620T000000   600000.0         2       1.00         1040      3600
# 12612  20140919T000000   225000.0         3       1.00         1290      8470
# 1815   20150407T000000   477000.0         3       2.25         1260      3000
# 10139  20141208T000000   800000.0         3       1.75         1890     10292
# 17060  20140610T000000   700000.0         5       2.75         3100      9825
# 12117  20141211T000000   585000.0         2       1.75         1830      7200
# 12576  20141028T000000   309500.0         3       1.00         1250      7320
# 20507  20150317T000000   280000.0         3       2.50         1608      4818
# 14632  20150226T000000   267000.0         4       1.75         2000      7350
# 18271  20150102T000000   238000.0         2       1.00          750      6480
# 1378   20140917T000000   279200.0         1       1.00          640      6350
# 17394  20140825T000000   145000.0         1       0.75          480      9750
# 11463  20150211T000000   199000.0         3       2.50         1750      6725
# 12453  20150402T000000   305000.0         2       1.00          910     22725
# 19617  20141219T000000   450000.0         3       1.00         1150     35415
# 18267  20141210T000000   385000.0         4       2.50         2030     11375
# 2294   20140910T000000   260000.0         3       1.50         1320      9750
# 15655  20140617T000000   400000.0         3       2.25         2140     11266
# 163    20140620T000000   441000.0         3       2.75         1910      7280
# 7175   20140902T000000   570000.0         3       1.50         1980     10203
# 17561  20140818T000000   833000.0         4       3.50         3560      7178
#
#        floors  condition  grade  sqft_above  sqft_basement  yr_built      lat  \
# 8598      1.0          4      7        1520              0      1968  47.3980
# 14759     1.0          3      7         900            430      1971  47.4239
# 18857     1.0          4      7        1020           1020      1961  47.5941
# 12112     1.0          3      7        1420              0      1959  47.6940
# 18220     2.0          4      7        1370              0      1993  47.3504
# 17831     2.0          4      8        1480              0      1914  47.6095
# 20262     2.0          3      8        3220              0      2006  47.7273
# 2177      1.0          4      9        2150           1480      1972  47.5610
# 13618     1.0          3      7         900            500      1922  47.4866
# 1701      1.0          4      7        1040              0      1919  47.6190
# 12612     1.0          4      7         970            320      1966  47.3054
# 1815      2.0          3      7        1260              0      2003  47.5459
# 10139     1.0          4      8        1890              0      1969  47.5350
# 17060     2.0          4      8        3100              0      1950  47.7188
# 12117     1.0          4      7        1070            760      1949  47.5592
# 12576     1.0          3      7        1250              0      1968  47.5074
# 20507     2.0          3      8        1608              0      2012  47.2583
# 14632     1.0          3      7        1100            900      1963  47.3428
# 18271     1.0          3      6         750              0      1943  47.5195
# 1378      1.0          3      5         640              0      1939  47.6976
# 17394     1.0          2      4         480              0      1948  47.4982
# 11463     1.0          3      7        1330            420      1993  47.3520
# 12453     1.0          1      6         910              0      1926  47.7712
# 19617     1.0          4      7        1010            140      1950  47.5974
# 18267     1.0          3      7        1330            700      1969  47.7765
# 2294      1.0          3      7        1320              0      1954  47.4267
# 15655     2.0          3      7        2140              0      1986  47.7267
# 163       1.0          3      7        1160            750      1979  47.7319
# 7175      1.0          4      7        1680            300      1946  47.3402
# 17561     2.0          3     10        2590            970      2006  47.7054
#
#           long  sqft_living15  sqft_lot15
# 8598  -121.964           1580       18618
# 14759 -122.292           1400       11500
# 18857 -122.144           1720        7344
# 12112 -122.332           1540        6375
# 18220 -122.035           1370        6600
# 17831 -122.296           1280        3600
# 20262 -121.958           3020        9300
# 2177  -122.226           3150       13555
# 13618 -122.219           1400        5500
# 1701  -122.311           2250        4800
# 12612 -122.371           1300        7350
# 1815  -121.997           1630        3023
# 10139 -122.234           2630       10625
# 17060 -122.281           2120        8400
# 12117 -122.273           1570        6000
# 12576 -122.163           1770        7320
# 20507 -122.203           2009        5200
# 14632 -122.303           1720        7350
# 18271 -122.350           1050        6390
# 1378  -122.359           1270        6350
# 17394 -122.362           1550        9924
# 11463 -122.058           1670        7744
# 12453 -122.299           2000       14566
# 19617 -122.129           2460       11781
# 18267 -122.261           1500        9160
# 2294  -122.331           1530        9750
# 15655 -121.966           2000       14174
# 163   -122.224           1710        8152
# 7175  -122.046           1980       13664
# 17561 -122.107           3290        6978

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **1-** shape of the data

# %% [markdown]
# **2-** Data types

# %% [markdown]
# **3-** Null values

# %% [markdown]
# **4-** Duplicates

# %% [markdown]
# **5-** Statistical Summary

# %% [markdown]
# # Shape

# %%
house.shape
# Out:
# (21613, 16)

# %% [markdown]
# **DataSet contain 21613 rows and 19 columns**

# %% [markdown]
# # Datatypes

# %%
house.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# # Change the datatype of Date column

# %%
house['date']=pd.to_datetime(house['date'])

# %%
house.dtypes
# Out:
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# # Null values

# %%
house.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# **There is no null values in this dataset**

# %% [markdown]
# # Duplicates

# %%
house.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are no duplicates records **

# %% [markdown]
# # Statistical Summary

# %%
house.describe()
# Out:
#                                 date         price      bedrooms  \
# count                          21613  2.161300e+04  21613.000000
# mean   2014-10-29 04:38:01.959931648  5.400881e+05      3.370842
# min              2014-05-02 00:00:00  7.500000e+04      0.000000
# 25%              2014-07-22 00:00:00  3.219500e+05      3.000000
# 50%              2014-10-16 00:00:00  4.500000e+05      3.000000
# 75%              2015-02-17 00:00:00  6.450000e+05      4.000000
# max              2015-05-27 00:00:00  7.700000e+06     33.000000
# std                              NaN  3.671272e+05      0.930062
#
#           bathrooms   sqft_living      sqft_lot        floors     condition  \
# count  21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# mean       2.114757   2079.899736  1.510697e+04      1.494309      3.409430
# min        0.000000    290.000000  5.200000e+02      1.000000      1.000000
# 25%        1.750000   1427.000000  5.040000e+03      1.000000      3.000000
# 50%        2.250000   1910.000000  7.618000e+03      1.500000      3.000000
# 75%        2.500000   2550.000000  1.068800e+04      2.000000      4.000000
# max        8.000000  13540.000000  1.651359e+06      3.500000      5.000000
# std        0.770163    918.440897  4.142051e+04      0.539989      0.650743
#
#               grade    sqft_above  sqft_basement      yr_built           lat  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     47.560053
# min        1.000000    290.000000       0.000000   1900.000000     47.155900
# 25%        7.000000   1190.000000       0.000000   1951.000000     47.471000
# 50%        7.000000   1560.000000       0.000000   1975.000000     47.571800
# 75%        8.000000   2210.000000     560.000000   1997.000000     47.678000
# max       13.000000   9410.000000    4820.000000   2015.000000     47.777600
# std        1.175459    828.090978     442.575043     29.373411      0.138564
#
#                long  sqft_living15     sqft_lot15
# count  21613.000000   21613.000000   21613.000000
# mean    -122.213896    1986.552492   12768.455652
# min     -122.519000     399.000000     651.000000
# 25%     -122.328000    1490.000000    5100.000000
# 50%     -122.230000    1840.000000    7620.000000
# 75%     -122.125000    2360.000000   10083.000000
# max     -121.315000    6210.000000  871200.000000
# std        0.140828     685.391304   27304.179631

# %% [markdown]
# # Conculssion
# **1-** One house contain 33 bedrooms and 8 bathroom so these are the outliers so we can drop this house

# %%
house=house[~(house['bedrooms']==33)]

# %%
house.describe()
# Out:
#                                 date         price      bedrooms  \
# count                          21612  2.161200e+04  21612.000000
# mean   2014-10-29 04:46:26.451971328  5.400835e+05      3.369471
# min              2014-05-02 00:00:00  7.500000e+04      0.000000
# 25%              2014-07-22 00:00:00  3.218375e+05      3.000000
# 50%              2014-10-16 00:00:00  4.500000e+05      3.000000
# 75%              2015-02-17 00:00:00  6.450000e+05      4.000000
# max              2015-05-27 00:00:00  7.700000e+06     11.000000
# std                              NaN  3.671351e+05      0.907982
#
#           bathrooms   sqft_living      sqft_lot        floors     condition  \
# count  21612.000000  21612.000000  2.161200e+04  21612.000000  21612.000000
# mean       2.114774   2079.921016  1.510739e+04      1.494332      3.409356
# min        0.000000    290.000000  5.200000e+02      1.000000      1.000000
# 25%        1.750000   1426.500000  5.040000e+03      1.000000      3.000000
# 50%        2.250000   1910.000000  7.619000e+03      1.500000      3.000000
# 75%        2.500000   2550.000000  1.068825e+04      2.000000      4.000000
# max        8.000000  13540.000000  1.651359e+06      3.500000      5.000000
# std        0.770177    918.456818  4.142142e+04      0.539991      0.650668
#
#               grade    sqft_above  sqft_basement      yr_built           lat  \
# count  21612.000000  21612.000000   21612.000000  21612.000000  21612.000000
# mean       7.656904   1788.425319     291.495697   1971.006247     47.560047
# min        1.000000    290.000000       0.000000   1900.000000     47.155900
# 25%        7.000000   1190.000000       0.000000   1951.000000     47.470975
# 50%        7.000000   1560.000000       0.000000   1975.000000     47.571800
# 75%        8.000000   2210.000000     560.000000   1997.000000     47.678000
# max       13.000000   9410.000000    4820.000000   2015.000000     47.777600
# std        1.175477    828.094487     442.580931     29.373636      0.138564
#
#                long  sqft_living15     sqft_lot15
# count  21612.000000   21612.000000   21612.000000
# mean    -122.213891    1986.582871   12768.828984
# min     -122.519000     399.000000     651.000000
# 25%     -122.328000    1490.000000    5100.000000
# 50%     -122.230000    1840.000000    7620.000000
# 75%     -122.125000    2360.000000   10083.250000
# max     -121.315000    6210.000000  871200.000000
# std        0.140829     685.392610   27304.756179

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21612 entries, 0 to 21612
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21612 non-null  datetime64[ns]
#  1   price          21612 non-null  float64
#  2   bedrooms       21612 non-null  int64
#  3   bathrooms      21612 non-null  float64
#  4   sqft_living    21612 non-null  int64
#  5   sqft_lot       21612 non-null  int64
#  6   floors         21612 non-null  float64
#  7   condition      21612 non-null  int64
#  8   grade          21612 non-null  int64
#  9   sqft_above     21612 non-null  int64
#  10  sqft_basement  21612 non-null  int64
#  11  yr_built       21612 non-null  int64
#  12  lat            21612 non-null  float64
#  13  long           21612 non-null  float64
#  14  sqft_living15  21612 non-null  int64
#  15  sqft_lot15     21612 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(10)
# memory usage: 2.8 MB

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
house.head(1)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3        1.0         1180      5650     1.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built      lat     long  \
# 0          3      7        1180              0      1955  47.5112 -122.257
#
#    sqft_living15  sqft_lot15
# 0           1340        5650

# %% [markdown]
# # Numerical Col

# %% [markdown]
# ## Price

# %% [markdown]
# **Function for ploting graph**

# %%
def distrubution(col):
    fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(20,8))
    ax1.set_title(f"Distrubution Of {col}")
    sns.histplot(house[col],ax=ax1)

    ax2.set_title(f"Distrubution Of {col}")
    sns.kdeplot(house[col],ax=ax2)

    ax3.set_title(f"Distrubution Of {col}")
    sns.boxplot(house[col],ax=ax3)
    plt.show()

# %%
house['price'].describe()
# Out:
# count    2.161200e+04
# mean     5.400835e+05
# std      3.671351e+05
# min      7.500000e+04
# 25%      3.218375e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
distrubution('price')

# %%
house['price'].skew()
# Out:
# 4.024033595653388

# %% [markdown]
# # Conclussion
# **we can see that there is a lot of outlier and data is right skewed**

# %%
house.head(1)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3        1.0         1180      5650     1.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built      lat     long  \
# 0          3      7        1180              0      1955  47.5112 -122.257
#
#    sqft_living15  sqft_lot15
# 0           1340        5650

# %% [markdown]
# **1-** In this Dataset we have `sqrt_living` and `sqrt_living15` both show the size of the hosue.
# **2-** So we can add new columns `total_sqrt_living`

# %%
house['total_sqft_living']=house['sqft_living']+house['sqft_living15']

# %% [markdown]
# **1-** similarly for `sqft_lot`
# **2-** So we can add new columns `total_sqrt_lot`

# %%
house['tottal_sqft_lot']=house['sqft_lot']+house['sqft_lot15']

# %%
house.rename(columns={'tottal_sqft_lot':'total_sqft_lot'},inplace=True)

# %%
house.head(1)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3        1.0         1180      5650     1.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built      lat     long  \
# 0          3      7        1180              0      1955  47.5112 -122.257
#
#    sqft_living15  sqft_lot15  total_sqft_living  total_sqft_lot
# 0           1340        5650               2520           11300

# %% [markdown]
# # Drop the `sqft_living` `sqft_lot` and `sqft_living15` `sqft_lot15`

# %%
house.drop(columns=['sqft_living', 'sqft_lot','sqft_living15','sqft_lot15'],inplace=True)

# %%
house.head()
# Out:
#         date     price  bedrooms  bathrooms  floors  condition  grade  \
# 0 2014-10-13  221900.0         3       1.00     1.0          3      7
# 1 2014-12-09  538000.0         3       2.25     2.0          3      7
# 2 2015-02-25  180000.0         2       1.00     1.0          3      6
# 3 2014-12-09  604000.0         4       3.00     1.0          5      7
# 4 2015-02-18  510000.0         3       2.00     1.0          3      8
#
#    sqft_above  sqft_basement  yr_built      lat     long  total_sqft_living  \
# 0        1180              0      1955  47.5112 -122.257               2520
# 1        2170            400      1951  47.7210 -122.319               4260
# 2         770              0      1933  47.7379 -122.233               3490
# 3        1050            910      1965  47.5208 -122.393               3320
# 4        1680              0      1987  47.6168 -122.045               3480
#
#    total_sqft_lot
# 0           11300
# 1           14881
# 2           18062
# 3           10000
# 4           15583

# %% [markdown]
# # sqft_above

# %%
house['sqft_above'].describe()
# Out:
# count    21612.000000
# mean      1788.425319
# std        828.094487
# min        290.000000
# 25%       1190.000000
# 50%       1560.000000
# 75%       2210.000000
# max       9410.000000
# Name: sqft_above, dtype: float64

# %%
distrubution('sqft_above')

# %% [markdown]
# # Conclussion
# **This column also contain certian outliers**

# %%
house.head(1)
# Out:
#         date     price  bedrooms  bathrooms  floors  condition  grade  \
# 0 2014-10-13  221900.0         3        1.0     1.0          3      7
#
#    sqft_above  sqft_basement  yr_built      lat     long  total_sqft_living  \
# 0        1180              0      1955  47.5112 -122.257               2520
#
#    total_sqft_lot
# 0           11300

# %%
house['sqft_basement'].describe()
# Out:
# count    21612.000000
# mean       291.495697
# std        442.580931
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        560.000000
# max       4820.000000
# Name: sqft_basement, dtype: float64

# %%
distrubution('sqft_basement')

# %%
house[house['sqft_basement']==0].shape
# Out:
# (13126, 14)

# %%
house[~(house['sqft_basement']==0)].shape
# Out:
# (8486, 14)

# %% [markdown]
# # Conclussion
# **1-** This column is also a quasi Constant columns b/c it contain lot of those value whose value can't be change.
# **2-** 13126 rows contain 0 and 8486 rows contain the other values

# %% [markdown]
# # Latitude

# %%
house.head(2)
# Out:
#         date     price  bedrooms  bathrooms  floors  condition  grade  \
# 0 2014-10-13  221900.0         3       1.00     1.0          3      7
# 1 2014-12-09  538000.0         3       2.25     2.0          3      7
#
#    sqft_above  sqft_basement  yr_built      lat     long  total_sqft_living  \
# 0        1180              0      1955  47.5112 -122.257               2520
# 1        2170            400      1951  47.7210 -122.319               4260
#
#    total_sqft_lot
# 0           11300
# 1           14881

# %%
house['lat'].describe()
# Out:
# count    21612.000000
# mean        47.560047
# std          0.138564
# min         47.155900
# 25%         47.470975
# 50%         47.571800
# 75%         47.678000
# max         47.777600
# Name: lat, dtype: float64

# %%
distrubution('lat')

# %% [markdown]
# # longitude

# %%
house['long'].describe()
# Out:
# count    21612.000000
# mean      -122.213891
# std          0.140829
# min       -122.519000
# 25%       -122.328000
# 50%       -122.230000
# 75%       -122.125000
# max       -121.315000
# Name: long, dtype: float64

# %%
distrubution('long')

# %% [markdown]
# # total_sqft_living

# %%
house['total_sqft_living'].describe()
# Out:
# count    21612.000000
# mean      4066.503887
# std       1505.211673
# min       1240.000000
# 25%       2960.000000
# 50%       3770.000000
# 75%       4870.000000
# max      18390.000000
# Name: total_sqft_living, dtype: float64

# %%
distrubution('total_sqft_living')

# %% [markdown]
# # total_sqft_lot

# %%
house.head(1)
# Out:
#         date     price  bedrooms  bathrooms  floors  condition  grade  \
# 0 2014-10-13  221900.0         3        1.0     1.0          3      7
#
#    sqft_above  sqft_basement  yr_built      lat     long  total_sqft_living  \
# 0        1180              0      1955  47.5112 -122.257               2520
#
#    total_sqft_lot
# 0           11300

# %%
house['total_sqft_lot'].describe()
# Out:
# count    2.161200e+04
# mean     2.787622e+04
# std      6.392699e+04
# min      1.438000e+03
# 25%      1.022000e+04
# 50%      1.537400e+04
# 75%      2.091600e+04
# max      2.076940e+06
# Name: total_sqft_lot, dtype: float64

# %%
distrubution('total_sqft_lot')

# %% [markdown]
# # Conclussion
# **This Columns conatain a lot of outlier so we can handle after check the correlation in bi variate analysis**

# %% [markdown]
# # Cat-col

# %% [markdown]
# # Bedrooms

# %%
house.head(1)
# Out:
#         date     price  bedrooms  bathrooms  floors  condition  grade  \
# 0 2014-10-13  221900.0         3        1.0     1.0          3      7
#
#    sqft_above  sqft_basement  yr_built      lat     long  total_sqft_living  \
# 0        1180              0      1955  47.5112 -122.257               2520
#
#    total_sqft_lot
# 0           11300

# %%
house['bedrooms'].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# Name: count, dtype: int64

# %% [markdown]
# **1-** we can see that there are `13 house` whose contain `0 bedroom` and `1 house` whos conatin 11 bedroom we will drop these rows

# %%
outliers=house[(house['bedrooms']==0) | (house['bedrooms']==11) | (house['bedrooms']==10) | (house['bedrooms']==9)].shape
print(outliers)
# Out:
# (23, 14)

# %% [markdown]
# **we can say that these are the outluiers**

# %%
house[(house['bedrooms']==0) | (house['bedrooms']==11) | (house['bedrooms']==10) | (house['bedrooms']==9)]
# Out:
#             date      price  bedrooms  bathrooms  floors  condition  grade  \
# 875   2014-06-12  1095000.0         0       0.00     3.5          3      7
# 3119  2015-02-05   380000.0         0       0.00     3.0          3      8
# 3467  2014-08-05   288000.0         0       1.50     3.0          3      7
# 4096  2014-05-07   599999.0         9       4.50     2.5          3      7
# 4235  2015-01-06   700000.0         9       3.00     2.0          3      7
# 4868  2014-10-02   228000.0         0       1.00     1.0          2      4
# 6079  2014-08-08  1280000.0         9       4.50     2.0          3      8
# 6994  2014-06-24  1295650.0         0       0.00     2.0          3     12
# 8477  2014-11-17   339950.0         0       2.50     2.0          3      8
# 8484  2014-09-25   240000.0         0       2.50     2.0          3      7
# 8546  2014-08-11   450000.0         9       7.50     2.0          3      7
# 8757  2014-08-21   520000.0        11       3.00     2.0          3      7
# 9773  2015-04-29   355000.0         0       0.00     2.0          3      8
# 9854  2014-12-23   235000.0         0       0.00     2.0          3      7
# 12653 2015-02-18   320000.0         0       2.50     2.0          3      7
# 13314 2014-08-14  1148000.0        10       5.25     1.0          3      9
# 14423 2015-04-13   139950.0         0       0.00     1.0          4      7
# 15161 2014-10-29   650000.0        10       2.00     2.0          4      7
# 16844 2015-03-17  1400000.0         9       4.00     2.5          3     11
# 18379 2014-10-29   265000.0         0       0.75     1.0          3      4
# 18443 2015-03-13   934000.0         9       3.00     2.0          3      7
# 19254 2014-12-29   660000.0        10       3.00     2.0          4      7
# 19452 2014-09-26   142000.0         0       0.00     1.0          1      1
#
#        sqft_above  sqft_basement  yr_built      lat     long  \
# 875          3064              0      1990  47.6362 -122.322
# 3119         1470              0      2006  47.7145 -122.356
# 3467         1430              0      1999  47.7222 -122.290
# 4096         2450           1380      1938  47.6927 -122.338
# 4235         2830            850      1908  47.6374 -122.324
# 4868          390              0      1953  47.5260 -122.261
# 6079         2530           1120      1915  47.6604 -122.289
# 6994         4810              0      1990  47.6642 -122.069
# 8477         2290              0      1985  47.3473 -122.151
# 8484         1810              0      2003  47.3493 -122.053
# 8546         4050              0      1996  47.5923 -122.301
# 8757         2400            600      1918  47.5560 -122.363
# 9773         2460              0      1990  47.4095 -122.168
# 9854         1470              0      1996  47.5265 -121.828
# 12653        1490              0      1999  47.5261 -121.826
# 13314        2500           2090      2008  47.5861 -122.113
# 14423         844              0      1913  47.2781 -122.250
# 15161        3010            600      1958  47.5705 -122.175
# 16844        3870            750      1915  47.6684 -122.309
# 18379         384              0      2003  47.4177 -122.491
# 18443        1880            940      1918  47.6654 -122.307
# 19254        1860           1060      1913  47.6635 -122.320
# 19452         290              0      1963  47.5308 -121.888
#
#        total_sqft_living  total_sqft_lot
# 875                 5424            8764
# 3119                2940            2378
# 3467                2860            3300
# 4096                5290           13279
# 4235                5640            6850
# 4868                2560           11900
# 6079                6160           10000
# 6994                9550           63069
# 8477                4790           17070
# 8484                3620           11354
# 8546                5498           10370
# 8757                4420            9920
# 9773                4980           16099
# 9854                2530           12000
# 12653               2990           11786
# 13314               7320           21320
# 14423               2224           13869
# 15161               5650           23828
# 16844               7330            9828
# 18379               2304          437785
# 18443               5280            8880
# 19254               4730            7490
# 19452               1910           43725

# %% [markdown]
# **There are 23 house whose conatin `0,9,10,11 bedrooms` we will drop it**

# %%
house[~((house['bedrooms']==0) | (house['bedrooms']==11) | (house['bedrooms']==10) | (house['bedrooms']==9))].shape
# Out:
# (21589, 14)

# %%
house=house[~((house['bedrooms']==0) | (house['bedrooms']==11) | (house['bedrooms']==10) | (house['bedrooms']==9))]

# %%
house.head(1)
# Out:
#         date     price  bedrooms  bathrooms  floors  condition  grade  \
# 0 2014-10-13  221900.0         3        1.0     1.0          3      7
#
#    sqft_above  sqft_basement  yr_built      lat     long  total_sqft_living  \
# 0        1180              0      1955  47.5112 -122.257               2520
#
#    total_sqft_lot
# 0           11300

# %%
house['bedrooms'].value_counts()
# Out:
# bedrooms
# 3    9824
# 4    6882
# 2    2760
# 5    1601
# 6     272
# 1     199
# 7      38
# 8      13
# Name: count, dtype: int64

# %%
house['bedrooms'].value_counts(normalize=True)*100
# Out:
# bedrooms
# 3    45.504655
# 4    31.877345
# 2    12.784288
# 5     7.415814
# 6     1.259901
# 1     0.921766
# 7     0.176016
# 8     0.060216
# Name: proportion, dtype: float64

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(20,8))
ax1.set_title("Bar chart og Bedrooms")
sns.barplot(data=house,
            x=house['bedrooms'].value_counts().index,
            y=house['bedrooms'].value_counts(),ax=ax1,palette="colorblind")
ax1.grid()

ax1.set_title("Pie chart og Bedrooms")
plt.pie(house['bedrooms'].value_counts(),
        labels=house['bedrooms'].value_counts().index,autopct="%.2f",
        shadow=True
)
ax1.grid()

# %% [markdown]
# # Bathrooms
